# %% [markdown]
# # 1. import the necessary libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
import plotly.express as px

# %% [markdown]
# # 2. Set a path of file

# %%
file_path = "/Users/evan/Documents/🤓/DSTI/3_Python_LAB/Books/Books_clean_evan.xlsx"

# %%
books = pd.read_excel(file_path)

# %% [markdown]
# # 3. Scan the data set

# %% [markdown]
# ### NB rows and NB columns

# %%
books
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %% [markdown]
# # Check the missing values

# %%
books.isna()
# Out:
#        bookID  title  authors  average_rating   isbn  isbn13  language_code  \
# 0       False  False    False           False  False   False          False
# 1       False  False    False           False  False   False          False
# 2       False  False    False           False  False   False          False
# 3       False  False    False           False  False   False          False
# 4       False  False    False           False  False   False          False
# ...       ...    ...      ...             ...    ...     ...            ...
# 11122   False  False    False           False  False   False          False
# 11123   False  False    False           False  False   False          False
# 11124   False  False    False           False  False   False          False
# 11125   False  False    False           False  False   False          False
# 11126   False  False    False           False  False   False          False
#
# ...

# %%
books.isna().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  1
# isbn13                3
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %% [markdown]
# # Look at the value counts

# %%
books.average_rating.value_counts()
# Out:
# average_rating
# 4.00    219
# 3.96    195
# 4.02    178
# 3.94    176
# 4.07    172
#        ...
# 4.91      1
# 3.10      1
# 3.03      1
# 2.99      1
# 2.33      1
# Name: count, Length: 209, dtype: int64

# %% [markdown]
# # Describe Data

# %%
books.describe()
# Out:
#              bookID  average_rating        isbn13     num_pages  \
# count  11127.000000    11127.000000  1.112400e+04  11127.000000
# mean   21310.938887        3.933631  9.759003e+12    336.376921
# std    13093.358023        0.352445  4.525169e+11    241.127305
# min        1.000000        0.000000  8.517427e+08      0.000000
# 25%    10287.000000        3.770000  9.780345e+12    192.000000
# 50%    20287.000000        3.960000  9.780582e+12    299.000000
# 75%    32104.500000        4.135000  9.780872e+12    416.000000
# max    45641.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112700e+04        11127.000000
# mean    1.793641e+04          541.854498
# std     1.124794e+05         2576.176608
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           46.000000
# 75%     4.993500e+03          237.500000
# max     4.597666e+06        94265.000000

# %% [markdown]
# # Data set

# %%
books.tail(5)
# Out:
#        bookID                                             title  \
# 11122   45631  Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                       You Bright and Risen Angels
# 11124   45634                   The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                       Poor People
# 11126   45641                       Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 11122  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11123                                William T. Vollmann            4.08
# 11124                                William T. Vollmann            3.96
# 11125                                William T. Vollmann            3.72
# 11126                                         Mark Twain            3.91
#
#              isbn        isbn13 language_code    num_pages  ratings_count  \
# ...

# %%
books.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %% [markdown]
# # Silicing Data

# %% [markdown]
# # Describle for Average_rating

# %%
(books.average_rating).describe()
# Out:
# count    11127.000000
# mean         3.933631
# std          0.352445
# min          0.000000
# 25%          3.770000
# 50%          3.960000
# 75%          4.135000
# max          5.000000
# Name: average_rating, dtype: float64

# %% [markdown]
# # Average_rating more than 4

# %%
books_av4 = books [books['average_rating']>4]

# %%
books_av4.describe()
# Out:
#              bookID  average_rating        isbn13    num_pages  ratings_count  \
# count   4735.000000     4735.000000  4.735000e+03  4735.000000   4.735000e+03
# mean   20737.281521        4.198929  9.760811e+12   374.375924   2.201569e+04
# std    12799.384323        0.154100  4.376564e+11   304.257839   1.197278e+05
# min        1.000000        4.010000  8.987060e+09     0.000000   0.000000e+00
# 25%    10082.000000        4.080000  9.780375e+12   192.000000   1.380000e+02
# 50%    19199.000000        4.170000  9.780672e+12   316.000000   9.190000e+02
# 75%    31089.500000        4.280000  9.780941e+12   472.000000   6.263500e+03
# max    45633.000000        5.000000  9.790008e+12  6576.000000   2.530894e+06
#
#        text_reviews_count
# count          4735.00000
# mean            630.45660
# std            2896.91091
# min               0.00000
# 25%              10.00000
# 50%              49.00000
# 75%             250.00000
# max           86881.00000

# %%
books.loc[books.average_rating>4]
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11116   45616       A Última Batalha (As Crónicas de Nárnia  #7)
# 11118   45623   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11119   45625  A Viagem do Caminheiro da Alvorada (As Crónica...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %% [markdown]
# # Correlation

# %%
books_processed = books.drop(columns=["bookID","isbn","publisher","title","authors","isbn13","language_code","publication_date"])

# %%
books_processed
# Out:
#        average_rating    num_pages  ratings_count  text_reviews_count
# 0                4.57          652        2095690               27591
# 1                4.49          870        2153167               29221
# 2                4.42          352           6333                 244
# 3                4.56          435        2339585               36325
# 4                4.78         2690          41428                 164
# ...               ...          ...            ...                 ...
# 11122            4.06          512            156                  20
# 11123            4.08          635            783                  56
# 11124            3.96          415            820                  95
# 11125            3.72          434            769                 139
# 11126            3.91          272            113                  12
#
# [11127 rows x 4 columns]

# %%
books_processed.corr()
# Out:
#                     average_rating    num_pages  ratings_count  \
# average_rating            1.000000     0.150809       0.038205
#   num_pages               0.150809     1.000000       0.034353
# ratings_count             0.038205     0.034353       1.000000
# text_reviews_count        0.033734     0.036998       0.865979
#
#                     text_reviews_count
# average_rating                0.033734
#   num_pages                   0.036998
# ratings_count                 0.865979
# text_reviews_count            1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(books_processed.corr(),annot=True)
plt.show()
